# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11932\1237737886.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Load the dataset
data = pd.read_csv('BA cia3 data.csv')

# %%
data
# Out:
#        Attrition_Flag_Encoded  Total_Trans_Ct  Total_Trans_Amt  \
# 0                           0              42             1144
# 1                           0              33             1291
# 2                           0              20             1887
# 3                           0              20             1171
# 4                           0              28              816
# ...                       ...             ...              ...
# 10122                       0             117            15476
# 10123                       1              69             8764
# 10124                       1              60            10291
# 10125                       1              62             8395
# 10126                       1              61            10294
#
#        Avg_Utilization_Ratio  Education_Level_Doctorate  \
# 0                      0.061                          0
# 1                      0.105                          0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Attrition_Flag_Encoded          10127 non-null  int64
#  1   Total_Trans_Ct                  10127 non-null  int64
#  2   Total_Trans_Amt                 10127 non-null  int64
#  3   Avg_Utilization_Ratio           10127 non-null  float64
#  4   Education_Level_Doctorate       10127 non-null  int64
#  5   Marital_Status_Married          10127 non-null  int64
#  6   Income_Category_Less than $40K  10127 non-null  int64
# dtypes: float64(1), int64(6)
# memory usage: 553.9 KB

# %%
data.corr()
# Out:
#                                 Attrition_Flag_Encoded  Total_Trans_Ct  \
# Attrition_Flag_Encoded                        1.000000       -0.371403
# Total_Trans_Ct                               -0.371403        1.000000
# Total_Trans_Amt                              -0.168598        0.807192
# Avg_Utilization_Ratio                        -0.178410        0.002838
# Education_Level_Doctorate                     0.029386       -0.009877
# Marital_Status_Married                       -0.023735       -0.123911
# Income_Category_Less than $40K                0.022466        0.040664
#
#                                 Total_Trans_Amt  Avg_Utilization_Ratio  \
# Attrition_Flag_Encoded                -0.168598              -0.178410
# Total_Trans_Ct                         0.807192               0.002838
# Total_Trans_Amt                        1.000000              -0.083034
# Avg_Utilization_Ratio                 -0.083034               1.000000
# ...

# %%
r=data.corr()
print(r)
# Out:
#                                 Attrition_Flag_Encoded  Total_Trans_Ct  \
# Attrition_Flag_Encoded                        1.000000       -0.371403
# Total_Trans_Ct                               -0.371403        1.000000
# Total_Trans_Amt                              -0.168598        0.807192
# Avg_Utilization_Ratio                        -0.178410        0.002838
# Education_Level_Doctorate                     0.029386       -0.009877
# Marital_Status_Married                       -0.023735       -0.123911
# Income_Category_Less than $40K                0.022466        0.040664
#
#                                 Total_Trans_Amt  Avg_Utilization_Ratio  \
# Attrition_Flag_Encoded                -0.168598              -0.178410
# Total_Trans_Ct                         0.807192               0.002838
# Total_Trans_Amt                        1.000000              -0.083034
# Avg_Utilization_Ratio                 -0.083034               1.000000
# ...

# %%
sns.heatmap(r)
# Out:
# <Axes: >

# %%
#define x and y variables 
x=data.drop(['Attrition_Flag_Encoded'], axis=1)
y=data['Attrition_Flag_Encoded']

# %%
x
# Out:
#        Total_Trans_Ct  Total_Trans_Amt  Avg_Utilization_Ratio  \
# 0                  42             1144                  0.061
# 1                  33             1291                  0.105
# 2                  20             1887                  0.000
# 3                  20             1171                  0.760
# 4                  28              816                  0.000
# ...               ...              ...                    ...
# 10122             117            15476                  0.462
# 10123              69             8764                  0.511
# 10124              60            10291                  0.000
# 10125              62             8395                  0.000
# 10126              61            10294                  0.189
#
#        Education_Level_Doctorate  Marital_Status_Married  \
# 0                              0                       1
# 1                              0                       0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.20)

# %%
print(xtrain)
xtrain.shape
# Out:
#       Total_Trans_Ct  Total_Trans_Amt  Avg_Utilization_Ratio  \
# 2782              60             3607                  0.580
# 5328              90             4926                  0.881
# 3085              40             1570                  0.246
# 5972              81             4051                  0.023
# 3467              76             3342                  0.000
# ...              ...              ...                    ...
# 6005              80             4384                  0.000
# 5342              84             3485                  0.166
# 3676              73             4869                  0.000
# 4815              44             2874                  0.000
# 9533              51             5385                  0.014
#
#       Education_Level_Doctorate  Marital_Status_Married  \
# 2782                          0                       1
# 5328                          0                       0
# 3085                          0                       1
# ...

# %%
print(ytrain)
ytrain.shape
# Out:
# 2782    0
# 5328    0
# 3085    0
# 5972    0
# 3467    0
#        ..
# 6005    0
# 5342    0
# 3676    0
# 4815    1
# 9533    1
# Name: Attrition_Flag_Encoded, Length: 8101, dtype: int64
# (8101,)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(x,y)
reg.score(x,y)
# Out:
# 0.22427730095996423

# %%
fig, axs=plt.subplots(1,3, sharey = True)
data.plot(kind='scatter', x='Total_Trans_Ct', y='Attrition_Flag_Encoded', ax=axs[0],figsize=(16,8))
data.plot(kind='scatter', x='Total_Trans_Amt', y='Attrition_Flag_Encoded', ax=axs[1])
data.plot(kind='scatter', x='Avg_Utilization_Ratio', y='Attrition_Flag_Encoded',ax=axs[2])
data.plot(kind='scatter', x='Marital_Status_Married', y='Attrition_Flag_Encoded',ax=axs[3])
data.plot(kind='scatter', x='Income_Category_Less than $40K', y='Attrition_Flag_Encoded',ax=axs[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 5
#       3 data.plot(kind='scatter', x='Total_Trans_Amt', y='Attrition_Flag_Encoded', ax=axs[1])
#       4 data.plot(kind='scatter', x='Avg_Utilization_Ratio', y='Attrition_Flag_Encoded',ax=axs[2])
# ----> 5 data.plot(kind='scatter', x='Marital_Status_Married', y='Attrition_Flag_Encoded',ax=axs[3])
#       6 data.plot(kind='scatter', x='Income_Category_Less than $40K', y='Attrition_Flag_Encoded',ax=axs[4])
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
import statsmodels.api as sm
mod = sm.OLS(y, x)  # Assuming y and x are properly defined
result = mod.fit()
print(result.summary())
# Out:
#                                    OLS Regression Results
# ...
# Dep. Variable:     Attrition_Flag_Encoded   R-squared (uncentered):                   0.106
# Model:                                OLS   Adj. R-squared (uncentered):              0.105
# Method:                     Least Squares   F-statistic:                              199.9
# Date:                    Fri, 12 Apr 2024   Prob (F-statistic):                   9.33e-242
# Time:                            11:38:06   Log-Likelihood:                         -4543.9
# No. Observations:                   10127   AIC:                                      9100.
# Df Residuals:                       10121   BIC:                                      9143.
# Df Model:                               6
# Covariance Type:                nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# ...
